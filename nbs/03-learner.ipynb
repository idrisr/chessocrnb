# %%
# default_exp learner

# %% [markdown]
# # Learner

# %%
#export
from fastcore.transform import *
from fastai.data.all import *
from fastai.vision.all import *
from fastai.test_utils import synth_learner
import pandas as pd
from pathlib import Path
from nbdev import show_doc
import os
import chessocr
from dataclasses import dataclass

# %%
#export
class NoLabelBBoxLabeler(Transform):
    """ Bounding box labeler with no label """
    def setups(self, x): noop
    def decode (self, x, **kwargs):
        self.bbox,self.lbls = None,None
        return self._call('decodes', x, **kwargs)

    def decodes(self, x:TensorBBox):
        self.bbox = x
        return self.bbox if self.lbls is None else LabeledBBox(self.bbox, self.lbls)

# %%
#export
class BBoxTruth:
    """ get bounding box location from DataFrame """
    def __init__(self, df): self.df=df
    def __call__(self, o):
        size,x,y,*_ =self.df.iloc[int(o.stem)-1]
        return [[x,y, x+size, y+size]]

# %%
#export
def iou(pred, target):
    """ Vectorized Intersection Over Union calculation """
    target = Tensor.cpu(target).squeeze(1)
    pred = Tensor.cpu(pred)
    ab = np.stack([pred, target])
    intersect_area = np.maximum(ab[:, :, [2, 3]].min(axis=0) - ab[:, :, [0, 1]].max(axis=0), 0).prod(axis=1)
    union_area = ((ab[:, :, 2] - ab[:, :, 0]) * (ab[:, :, 3] - ab[:, :, 1])).sum(axis=0) - intersect_area
    return (intersect_area / union_area).mean()

# %%
#export
NoLabelBBoxBlock = TransformBlock(type_tfms=TensorBBox.create, 
                             item_tfms=[PointScaler, NoLabelBBoxLabeler])

# %%
data_url = Path.home()/".fastai/data/chess"

# %%
df = pd.read_csv(data_url/'annotations.csv', index_col=0)

# %%
df
# Out:
#      size    x    y  \
# 0     229   37  339
# 1     382  477   74
# 2     491  435  146
# 3     427  530   62
# 4     568  360  159
# ..    ...  ...  ...
# 995   428  136  231
# 996   386  168  307
# 997   390  606   74
# 998   375  612   80
# 999   578   12  133
#
#                                                                background  \
# 0                 gizmodo_com_png.rf.f395c9cc8b5c8efa6eb1cca51498a0ee.jpg
# 1              openoffice_org_png.rf.811bd2a4fadde3fcfe99693de0bb0d8b.jpg
# 2      support_cloudflare_com_png.rf.f67cba6817cdec85c329a52303481045.jpg
# 3       feedburner_google_com_png.rf.7f02c68e38baa597fc3045b367d96a84.jpg
# 4                   500px_com_png.rf.f015eafe7d46f5c079c44eff3790befa.jpg
# ..                                                                    ...
# 995           helpx_adobe_com_png.rf.5468b4887d3d094a8729ac58a9a1f961.jpg
# 996  dictionary_reference_com_png.rf.3ab7b894c292a32c3528bcd6b81e54df.jpg
# 997      sherwin-williams_com_png.rf.0895fa8abf969eed0ae0bc677f64a49b.jpg
# 998         sciencedirect_com_png.rf.4f6ce25f0aae4a01858fb185f3e498b6.jpg
# 999              jsfiddle_net_png.rf.1466c37e41a23b0d51eb247869aef138.jpg
#
#                                                                   fen   board  \
# 0    _rbq_rk__p__bpppp_nppn_____________NP_PP__N_BP__PPPQ______KR_B_R   8.png
# 1    __r___k___q__pp__p__p__p________PR__P_____P___P______PKP_Q______  21.png
# 2    rnbq_k_rppp__pp_____p__p___pP______Pn_Q_P_P_B_____P__PPPR___KBNR  14.png
# 3    _____k________p________p__pP_p____Pqp____Q____PP_____PK_________   8.png
# 4    br_r__k_p___qp________pp__np_______P______N___PPP_R__P____RQ_BK_  24.png
# ..                                                                ...     ...
# 995  ______k______p___p____p_pPpQ____P_Pb__N______q_______r_P___R___K   9.png
# 996  ___rnk___pN____r__bp_Pp_p_p_____P_P__P___P__P_NB___R_K_____R____   4.png
# 997  rnbq_rk_ppp_ppbp___p_np___________PPP_____N__N__PP___PPPR_BQKB_R  15.png
# 998  __b___________kp__pn__p__pNp_p__pP_P__P___P_PB_PP_____________K_   8.png
# 999  r__r_bk______ppp__n____B___p_____________qN_R_Q______PPP_____RK_   4.png
#
#      pieceset
# 0          19
# 1          10
# 2          21
# 3          12
# 4           3
# ..        ...
# 995        23
# 996         2
# 997        10
# 998        18
# 999        25
#
# [1000 rows x 7 columns]

# %%
block = DataBlock(
    blocks=(ImageBlock, NoLabelBBoxBlock), 
    get_items=get_image_files,
    get_y=[BBoxTruth(df)],
    n_inp=1,
    item_tfms=[Resize(224)])

# %%
dls=block.dataloaders(data_url, batch_size=64)

# %%
# %matplotlib inline

# %%
dls.show_batch(max_n=9, figsize=(8, 8))

# %%
learn = cnn_learner(dls, resnet18, 
                    metrics=[iou], 
                    loss_func=MSELossFlat())
learn.model.cuda();
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File /Users/id/nbs/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py, in run_code:
# Line 3441:  exec(code_obj, self.user_global_ns, self.user_ns)
#
# In  [22]:
# Line 4:     learn.model.cuda();
#
# File /Users/id/nbs/venv/lib/python3.7/site-packages/torch/nn/modules/module.py, in cuda:
# Line 491:   return self._apply(lambda t: t.cuda(device))
#
# File /Users/id/nbs/venv/lib/python3.7/site-packages/torch/nn/modules/module.py, in _apply:
# Line 387:   module._apply(fn)
#
# File /Users/id/nbs/venv/lib/python3.7/site-packages/torch/nn/modules/module.py, in _apply:
# Line 387:   module._apply(fn)
#
# File /Users/id/nbs/venv/lib/python3.7/site-packages/torch/nn/modules/module.py, in _apply:
# Line 409:   param_applied = fn(param)
#
# File /Users/id/nbs/venv/lib/python3.7/site-packages/torch/nn/modules/module.py, in <lambda>:
# Line 491:   return self._apply(lambda t: t.cuda(device))
#
# File /Users/id/nbs/venv/lib/python3.7/site-packages/torch/cuda/__init__.py, in _lazy_init:
# Line 164:   raise AssertionError("Torch not compiled with CUDA enabled")
#
# AssertionError: Torch not compiled with CUDA enabled
# ---------------------------------------------------------------------------

# %%
# %debug
# Out:
# > /Users/id/nbs/venv/lib/python3.7/site-packages/torch/cuda/__init__.py(164)_lazy_init()
#     162                 "multiprocessing, you must use the 'spawn' start method")
#     163         if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 164             raise AssertionError("Torch not compiled with CUDA enabled")
#     165         if _cudart is None:
#     166             raise AssertionError(
# ipdb>  u
# > /Users/id/nbs/venv/lib/python3.7/site-packages/torch/nn/modules/module.py(491)<lambda>()
#     489             Module: self
#     490         """
# --> 491         return self._apply(lambda t: t.cuda(device))
#     492
#     493     def xpu(self: T, device: Optional[Union[int, device]] = None) -> T:
# ipdb>  q
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 357, in set_quit
#     sys.settrace(None)

# %%
d

# %%
learn.fine_tune(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>iou</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.101954</td>
#       <td>1.863479</td>
#       <td>0.020064</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>iou</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.577185</td>
#       <td>1.814246</td>
#       <td>0.027965</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.007805</td>
#       <td>1.713767</td>
#       <td>0.034635</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.822658</td>
#       <td>1.492343</td>
#       <td>0.047794</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.774136</td>
#       <td>1.424591</td>
#       <td>0.050156</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.757502</td>
#       <td>1.413293</td>
#       <td>0.058228</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.683643</td>
#       <td>1.377962</td>
#       <td>0.051977</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.616832</td>
#       <td>1.290937</td>
#       <td>0.055055</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.529407</td>
#       <td>1.231704</td>
#       <td>0.049979</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.491573</td>
#       <td>1.225529</td>
#       <td>0.040197</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.492786</td>
#       <td>1.214628</td>
#       <td>0.041716</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()

# %%
learn.save("mymodel.pth")
# Out:
# Path('models/mymodel.pth.pth')

# %%
learn.summary()
# Out:
# Sequential (Input shape: 64)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      64 x 64 x 112 x 112
# Conv2d                                    9408       True
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ReLU
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ReLU
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      64 x 128 x 28 x 28
# Conv2d                                    73728      True
# BatchNorm2d                               256        True
# ReLU
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# Conv2d                                    8192       True
# BatchNorm2d                               256        True
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ReLU
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 256 x 14 x 14
# Conv2d                                    294912     True
# BatchNorm2d                               512        True
# ReLU
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# Conv2d                                    32768      True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ReLU
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 512 x 7 x 7
# Conv2d                                    1179648    True
# BatchNorm2d                               1024       True
# ReLU
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# Conv2d                                    131072     True
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# ReLU
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      []
# AdaptiveAvgPool2d
# AdaptiveMaxPool2d
# Flatten
# BatchNorm1d                               2048       True
# Dropout
# ____________________________________________________________________________
#                      64 x 512
# Linear                                    524288     True
# ReLU
# BatchNorm1d                               1024       True
# Dropout
# ____________________________________________________________________________
#                      64 x 4
# Linear                                    2048       True
# ____________________________________________________________________________
#
# Total params: 11,705,920
# Total trainable params: 11,705,920
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x7f2dae3f8790>
# Loss function: FlattenedLoss of MSELoss()
#
# Model unfrozen
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback
